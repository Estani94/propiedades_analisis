# %%
import pandas as pd

# Cargar el CSV limpio
df = pd.read_csv("propiedades_limpias_tipo.csv")

# Asegurar conversiones numéricas
df['Ambientes'] = pd.to_numeric(df['Ambientes'], errors='coerce')
df['Baños'] = pd.to_numeric(df['Baños'], errors='coerce')

# 1. Precio por m²
df['Precio por m2'] = df['Precio USD'] / df['M2 Totales']

# 4. Rango de precio por cuartiles
df['Rango de precio'] = pd.qcut(df['Precio USD'], q=4, labels=['Muy bajo', 'Bajo', 'Medio', 'Alto'])

# 5. Rango de superficie por cuartiles
df['Rango de superficie'] = pd.qcut(df['M2 Totales'], q=4, labels=['Chico', 'Mediano', 'Grande', 'Muy grande'])

# 6. Densidad de ambientes
df['Densidad ambientes'] = df['Ambientes'] / df['M2 Totales']

df
# Out:
#                                                  Nombre  Precio USD  \
# 0           DEPARTAMENTO 2 DORMITORIOS - SOBRE PEATONAL       75000
# 1     Dpto 2 dorm. MUNDO Bv. GALVEZ 1712 PLAZA PUYRR...      345000
# 2     Dpto 2 dorm. MUNDO Bv. GALVEZ 1712 PLAZA PUYRR...      330000
# 3                   Importante casa en Villa California      250000
# 4     Se Vende Departamento dos dormitorios Zona Cen...       63000
# ...                                                 ...         ...
# 1547   VENTA DEPARTAMENTO DE DOS DORMITORIOS FINANCIADO       45000
# 1548        OPORTUNIDAD VENTA DEPARTAMENTO 1 DORMITORIO       38000
# 1549               Dpto 2 Dormitorios | TORRE CAPITAL |      168000
# 1550          Dpto Piso 3 Dormitorios | TORRE CAPITAL |      369000
# 1551                      COCHERA BARRIO CONSTITUYENTES        9000
#
#                            Dirección  M2 Totales  Ambientes  Baños  \
# 0                    San Martín 2000       46.46        4.0    1.0
# 1              Boulevard Gálvez 1700      110.00        3.0    2.0
# 2              Boulevard Gálvez 1700      110.00        3.0    2.0
# 3                    Río de Oro 2800      412.00        7.0    4.0
# 4                      La Rioja 2900       66.00        3.0    1.0
# ...                              ...         ...        ...    ...
# 1547            Obispo Gelabert 1800       36.00        1.0    1.0
# 1548  Avenida Gobernador Freyre 1700       42.00        2.0    1.0
# 1549      Avenida General López 2800       91.00        4.0    2.0
# 1550      Avenida General López 2800      188.00        6.0    3.0
# 1551                  1 de Mayo 3200       12.50        NaN    NaN
#
#               Tipo  Precio por m2 Rango de precio Rango de superficie  \
# 0     Departamento    1614.291864            Bajo               Chico
# 1     Departamento    3136.363636            Alto             Mediano
# 2     Departamento    3000.000000            Alto             Mediano
# 3             Casa     606.796117            Alto          Muy grande
# 4     Departamento     954.545455            Bajo             Mediano
# ...            ...            ...             ...                 ...
# 1547  Departamento    1250.000000        Muy bajo               Chico
# 1548  Departamento     904.761905        Muy bajo               Chico
# 1549  Departamento    1846.153846            Alto             Mediano
# 1550  Departamento    1962.765957            Alto              Grande
# 1551       Cochera     720.000000        Muy bajo               Chico
#
#       Densidad ambientes
# 0               0.086096
# 1               0.027273
# 2               0.027273
# 3               0.016990
# 4               0.045455
# ...                  ...
# 1547            0.027778
# 1548            0.047619
# 1549            0.043956
# 1550            0.031915
# 1551                 NaN
#
# [1552 rows x 11 columns]

# %%
import streamlit as st
import matplotlib.pyplot as plt

# Agrupar por rango de precio
precio_stats = df.groupby('Rango de precio', observed=True).agg(
    Cantidad=('Precio USD', 'count'),
    Promedio_precio=('Precio USD', 'mean'),
    Min_precio=('Precio USD', 'min'),
    Max_precio=('Precio USD', 'max')
).reset_index()

# Agrupar por rango de superficie
superficie_stats = df.groupby('Rango de superficie', observed=True).agg(
    Cantidad=('M2 Totales', 'count'),
    Promedio_m2=('M2 Totales', 'mean'),
    Min_m2=('M2 Totales', 'min'),
    Max_m2=('M2 Totales', 'max')
).reset_index()

st.title("Dashboard Propiedades")

st.subheader("Estadísticas por rango de precio")
st.dataframe(precio_stats)

fig, ax = plt.subplots()
ax.bar(precio_stats['Rango de precio'], precio_stats['Cantidad'])
ax.set_xlabel('Rango de precio')
ax.set_ylabel('Cantidad de propiedades')
ax.set_title('Cantidad de propiedades por rango de precio')
plt.xticks(rotation=45)
st.pyplot(fig)

st.subheader("Estadísticas por rango de superficie")
st.dataframe(superficie_stats)

fig2, ax2 = plt.subplots()
ax2.bar(superficie_stats['Rango de superficie'], superficie_stats['Cantidad'])
ax2.set_xlabel('Rango de superficie')
ax2.set_ylabel('Cantidad de propiedades')
ax2.set_title('Cantidad de propiedades por rango de superficie')
plt.xticks(rotation=45)
st.pyplot(fig2)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# 2025-05-25 22:55:39.513 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 22:55:39.817
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\estan\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-05-25 22:55:39.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 22:55:39.820 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 22:55:39.822 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 22:55:40.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 22:55:40.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 22:55:40.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 22:55:41.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 22:55:41.218 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 22:55:41.219 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 22:55:41.219 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 22:55:41.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 22:55:41.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 22:55:41.240 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 22:55:41.425 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 22:55:41.426 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
